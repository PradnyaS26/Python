# %% [markdown]
# #Complex Assignment

# %% [markdown]
# ---
#
# Q.1) Declare a complex number and store it in a variable.
# Check the type and print the id of the same.

# %%
complex1=6+2j
print(type(complex1))
print(id(complex1))

# Output :

# <class 'complex'>
# 133613804761744
# Out:
# <class 'complex'>
# 133613804761744

# %% [markdown]
# ---
#
# Q.2) Arithmetic Operations on complex number
#
# Take two different complex numbers. Store them in two different variables.
#
# Do below operations on them:-
# * Find sum of both numbers
# * Find difference between them
# * Find the product of both numbers.
# * Find value after dividing first num with second number
# * Find the result of the first num to the power of the second number.

# %%
complex2 = 2+3j
complex3 = 4+5j
print("complex2+complex3 : {}".format(complex2+complex3))
print("complex2-complex3 : {}".format(complex2-complex3))
print("complex2*complex3 : {}".format(complex2*complex3))
print("complex2/complex3 : {}".format(complex2/complex3))
print("complex2**complex3 : {}".format(complex2**complex3))

# Output :

# complex2+complex3 : (6+8j)
# complex2-complex3 : (-2-2j)
# complex2*complex3 : (-7+22j)
# complex2/complex3 : (0.5609756097560976+0.0487804878048781j)
# complex2**complex3 : (-0.7530458367485594-0.9864287886477446j)
# Out:
# complex2+complex3 : (6+8j)
# complex2-complex3 : (-2-2j)
# complex2*complex3 : (-7+22j)
# complex2/complex3 : (0.5609756097560976+0.0487804878048781j)
# complex2**complex3 : (-0.7530458367485594-0.9864287886477446j)

# %% [markdown]
# ---
#
# Q.3) Comparison Operation not applicable between instance of complex
# values.
#
# Object reusability concept is not applicable on complex number

# %% [markdown]
# ---
# Q.4) Equality Operator
#
# Take two different complex numbers. Store them in two different variables.
#
# Equate them using equality operators (==, !=).
# Observe the output(return type should be boolean)

# %%
complex4 = 7+3j
complex5 = 4+9j
print(complex4==complex5)
print(complex4!=complex5)

# Output :

# False
# True
# Out:
# False
# True

# %% [markdown]
# ---
#
# Q.5) Logical operators
#
# Observe the output of below code. Cross check the output manually.
# * print(10+20j and 20+30j) #20+30j -> Output is 20+30j
# * print(0+0j and 20+30j) #0+0j -> Output is 0j
# * print(20+30j and 0+0j) #0+0j -> Output is 0j
# * print(0+0j and 0+0j) #0+0j -> Output is 0j
# * print(10+20j or 20+30j) #10+20j -> Output is 10+20j
# * print(0+0j or 20+30j) #20+30j -> Output is 20+30j
# * print(20+30j or 0+0j) #20+30j -> Output is 20+30j
# * print(0+0j or 0+0j) #0+0j -> Output is 0j
# * print(not 10+20j) #False -> Output is False
# * print(not 0+0j) #True -> Output is True

# %%
print("10+20j and 20+30j : {}".format(10+20j and 20+30j))
print("0+0j and 20+30j : {}".format(0+0j and 20+30j))
print("20+30j and 0+0j : {}".format(20+30j and 0+0j))
print("0+0j and 0+0j : {}\n".format(0+0j and 0+0j))

print("10+20j or 20+30j : {}".format(10+20j or 20+30j))
print("0+0j or 20+30j : {}".format(0+0j or 20+30j))
print("20+30j or 0+0j : {}".format(20+30j or 0+0j))
print("0+0j or 0+0j : {}\n".format(0+0j or 0+0j))

print("not 10+20j : {}".format(not 10+20j))
print("not 0+0j : {}".format(not 0+0j))


# Output :

# 10+20j and 20+30j : (20+30j)
# 0+0j and 20+30j : 0j
# 20+30j and 0+0j : 0j
# 0+0j and 0+0j : 0j

# 10+20j or 20+30j : (10+20j)
# 0+0j or 20+30j : (20+30j)
# 20+30j or 0+0j : (20+30j)
# 0+0j or 0+0j : 0j

# not 10+20j : False
# not 0+0j : True
# Out:
# 10+20j and 20+30j : (20+30j)
# 0+0j and 20+30j : 0j
# 20+30j and 0+0j : 0j
# 0+0j and 0+0j : 0j
#
# 10+20j or 20+30j : (10+20j)
# 0+0j or 20+30j : (20+30j)
# 20+30j or 0+0j : (20+30j)
# 0+0j or 0+0j : 0j
#
# not 10+20j : False
# not 0+0j : True

# %% [markdown]
# ---
# Q.6) What is the output of the expression inside the print statement.Cross check before running the program.
#
# a = 10+20j
#
# b = 10+20j
#
# print(a is b) #False #True or False?
#
# print(a is not b) #True #True or False?

# %%
a = 10+20j
b = 10+20j

print(a is b)
print(a is not b)

# Output:

# False
# True
# Out:
# False
# True

# %% [markdown]
# ---
# Q.7) Membership operation
#
# in, not in are two membership operators and it returns boolean value
#
# * print('2.7' in 'Python2.7.8') #True
# * print(10+20j in [10,10.20,10+20j,'Python']) #True
# * print(10+20j in (10,10.20,10+20j,'Python')) #True
# * print(30+40j in {1,20.30,30+40j}) #True
# * print(30+40j in {1:100, 2.3:200, 30+40j:300}) #True
# * print(10 in range(20)) #True

# %%
print('2.7' in 'Python2.7.8')
print(10+20j in [10,10.20,10+20j,'Python'])
print(10+20j in (10,10.20,10+20j,'Python'))
print(30+40j in {1,20.30,30+40j})
print(30+40j in {1:100, 2.3:200, 30+40j:300})
print(10 in range(20))

Output :

# True
# True
# True
# True
# True
# True
# Out:
# True
# True
# True
# True
# True
# True
